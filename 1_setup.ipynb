# %% [markdown]
# ## MMSegmentation Package Setup

# %%
# !conda update -n base -c defaults conda -y
# Install PyTorch
# !conda install pytorch==1.12.0 torchvision==0.13.0 torchaudio==0.12.0 cudatoolkit=11.3 -c pytorch -y
# !conda install pytorch torchvision -c pytorch -y
# Install mim
# !pip install -U openmim
# Install mmengine
# !mim install mmengine
# Install MMCV
# !mim install 'mmcv >= 2.0.0rc1'
# Install CV2
# !pip install opencv-python opencv-python-headless
# Install MMSegmentation
# !rm -rf mmsegmentation
# !git clone -b main https://github.com/open-mmlab/mmsegmentation.git
# %cd mmsegmentation
# !pip install -e .
# !pip install ftfy
# !mim install mmsegmentation
# Out:
# Channels:
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Channels:
#  - pytorch
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Requirement already satisfied: openmim in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (0.3.9)
# Requirement already satisfied: Click in /home/codespace/.local/lib/python3.10/site-packages (from openmim) (8.1.7)
# Requirement already satisfied: colorama in /home/codespace/.local/lib/python3.10/site-packages (from openmim) (0.4.6)
# Requirement already satisfied: model-index in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from openmim) (0.1.11)
# Requirement already satisfied: opendatalab in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from openmim) (0.0.10)
# Requirement already satisfied: pandas in /home/codespace/.local/lib/python3.10/site-packages (from openmim) (2.1.3)
# Requirement already satisfied: pip>=19.3 in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from openmim) (23.3.1)
# Requirement already satisfied: requests in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from openmim) (2.28.2)
# Requirement already satisfied: rich in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from openmim) (13.4.2)
# Requirement already satisfied: tabulate in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from openmim) (0.9.0)
# Requirement already satisfied: pyyaml in /home/codespace/.local/lib/python3.10/site-packages (from model-index->openmim) (6.0.1)
# Requirement already satisfied: markdown in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from model-index->openmim) (3.5.1)
# Requirement already satisfied: ordered-set in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from model-index->openmim) (4.1.0)
# Requirement already satisfied: pycryptodome in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from opendatalab->openmim) (3.19.0)
# Requirement already satisfied: tqdm in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from opendatalab->openmim) (4.65.2)
# Requirement already satisfied: openxlab in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from opendatalab->openmim) (0.0.31)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests->openmim) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests->openmim) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from requests->openmim) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests->openmim) (2023.11.17)
# Requirement already satisfied: numpy<2,>=1.22.4 in /home/codespace/.local/lib/python3.10/site-packages (from pandas->openmim) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.10/site-packages (from pandas->openmim) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.10/site-packages (from pandas->openmim) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/codespace/.local/lib/python3.10/site-packages (from pandas->openmim) (2023.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from rich->openmim) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/codespace/.local/lib/python3.10/site-packages (from rich->openmim) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->openmim) (0.1.2)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->openmim) (1.16.0)
# Requirement already satisfied: oss2~=2.17.0 in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from openxlab->opendatalab->openmim) (2.17.0)
# Requirement already satisfied: setuptools~=60.2.0 in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from openxlab->opendatalab->openmim) (60.2.0)
# Requirement already satisfied: crcmod>=1.7 in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim) (1.7)
# Requirement already satisfied: aliyun-python-sdk-kms>=2.4.1 in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim) (2.16.2)
# Requirement already satisfied: aliyun-python-sdk-core>=2.13.12 in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim) (2.14.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.9.3 in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (0.10.0)
# Requirement already satisfied: cryptography>=2.6.0 in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (41.0.7)
# Requirement already satisfied: cffi>=1.12 in /home/codespace/.local/lib/python3.10/site-packages (from cryptography>=2.6.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (1.16.0)
# Requirement already satisfied: pycparser in /home/codespace/.local/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=2.6.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (2.21)
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu121/torch2.1.0/index.html
# Requirement already satisfied: mmengine in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (0.10.1)
# Requirement already satisfied: addict in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from mmengine) (2.4.0)
# Requirement already satisfied: matplotlib in /home/codespace/.local/lib/python3.10/site-packages (from mmengine) (3.8.1)
# Requirement already satisfied: numpy in /home/codespace/.local/lib/python3.10/site-packages (from mmengine) (1.26.2)
# Requirement already satisfied: pyyaml in /home/codespace/.local/lib/python3.10/site-packages (from mmengine) (6.0.1)
# Requirement already satisfied: rich in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from mmengine) (13.4.2)
# Requirement already satisfied: termcolor in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from mmengine) (2.4.0)
# Requirement already satisfied: yapf in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from mmengine) (0.40.2)
# Requirement already satisfied: opencv-python>=3 in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from mmengine) (4.8.1.78)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->mmengine) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->mmengine) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->mmengine) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->mmengine) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->mmengine) (23.2)
# Requirement already satisfied: pillow>=8 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->mmengine) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->mmengine) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->mmengine) (2.8.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from rich->mmengine) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/codespace/.local/lib/python3.10/site-packages (from rich->mmengine) (2.16.1)
# Requirement already satisfied: importlib-metadata>=6.6.0 in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from yapf->mmengine) (7.0.0)
# Requirement already satisfied: platformdirs>=3.5.1 in /home/codespace/.local/lib/python3.10/site-packages (from yapf->mmengine) (4.0.0)
# Requirement already satisfied: tomli>=2.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from yapf->mmengine) (2.0.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from importlib-metadata>=6.6.0->yapf->mmengine) (3.17.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->mmengine) (0.1.2)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->mmengine) (1.16.0)
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu121/torch2.1.0/index.html
# Requirement already satisfied: mmcv>=2.0.0rc1 in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (2.1.0)
# Requirement already satisfied: addict in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from mmcv>=2.0.0rc1) (2.4.0)
# Requirement already satisfied: mmengine>=0.3.0 in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from mmcv>=2.0.0rc1) (0.10.1)
# Requirement already satisfied: numpy in /home/codespace/.local/lib/python3.10/site-packages (from mmcv>=2.0.0rc1) (1.26.2)
# Requirement already satisfied: packaging in /home/codespace/.local/lib/python3.10/site-packages (from mmcv>=2.0.0rc1) (23.2)
# Requirement already satisfied: Pillow in /home/codespace/.local/lib/python3.10/site-packages (from mmcv>=2.0.0rc1) (10.1.0)
# Requirement already satisfied: pyyaml in /home/codespace/.local/lib/python3.10/site-packages (from mmcv>=2.0.0rc1) (6.0.1)
# Requirement already satisfied: yapf in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from mmcv>=2.0.0rc1) (0.40.2)
# Requirement already satisfied: opencv-python>=3 in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from mmcv>=2.0.0rc1) (4.8.1.78)
# Requirement already satisfied: matplotlib in /home/codespace/.local/lib/python3.10/site-packages (from mmengine>=0.3.0->mmcv>=2.0.0rc1) (3.8.1)
# Requirement already satisfied: rich in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from mmengine>=0.3.0->mmcv>=2.0.0rc1) (13.4.2)
# Requirement already satisfied: termcolor in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from mmengine>=0.3.0->mmcv>=2.0.0rc1) (2.4.0)
# Requirement already satisfied: importlib-metadata>=6.6.0 in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from yapf->mmcv>=2.0.0rc1) (7.0.0)
# Requirement already satisfied: platformdirs>=3.5.1 in /home/codespace/.local/lib/python3.10/site-packages (from yapf->mmcv>=2.0.0rc1) (4.0.0)
# Requirement already satisfied: tomli>=2.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from yapf->mmcv>=2.0.0rc1) (2.0.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from importlib-metadata>=6.6.0->yapf->mmcv>=2.0.0rc1) (3.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc1) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc1) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc1) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc1) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc1) (2.8.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from rich->mmengine>=0.3.0->mmcv>=2.0.0rc1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/codespace/.local/lib/python3.10/site-packages (from rich->mmengine>=0.3.0->mmcv>=2.0.0rc1) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->mmengine>=0.3.0->mmcv>=2.0.0rc1) (0.1.2)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc1) (1.16.0)
# Requirement already satisfied: opencv-python in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (4.8.1.78)
# Requirement already satisfied: opencv-python-headless in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (4.8.1.78)
# Requirement already satisfied: numpy>=1.21.2 in /home/codespace/.local/lib/python3.10/site-packages (from opencv-python) (1.26.2)
# Cloning into 'mmsegmentation'...
# remote: Enumerating objects: 16316, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 16316 (delta 5), reused 9 (delta 0), pack-reused 16289
# Receiving objects: 100% (16316/16316), 22.80 MiB | 26.15 MiB/s, done.
# Resolving deltas: 100% (11375/11375), done.
# /workspaces/ECE661GroupProject_TransferLearning/mmsegmentation
# /home/codespace/.local/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# Obtaining file:///workspaces/ECE661GroupProject_TransferLearning/mmsegmentation
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [35 lines of output]
#       /opt/conda/envs/openmmlab/lib/python3.10/site-packages/setuptools/dist.py:804: SetuptoolsDeprecationWarning: Deprecated API usage.
#       !!
#
#               ********************************************************************************
#               As setuptools moves its configuration towards `pyproject.toml`,
#               `setuptools.config.parse_configuration` became deprecated.
#
#               For the time being, you can use the `setuptools.config.setupcfg` module
#               to access a backward compatible API, but this module is provisional
#               and might be removed in the future.
#
#               To read project metadata, consider using
#               ``build.util.project_wheel_metadata`` (https://pypi.org/project/build/).
#               For simple scenarios, you can also try parsing the file directly
#               with the help of ``configparser``.
#               ********************************************************************************
#
#       !!
#         parse_configuration(
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/workspaces/ECE661GroupProject_TransferLearning/mmsegmentation/setup.py", line 169, in <module>
#           setup(
#         File "/opt/conda/envs/openmmlab/lib/python3.10/site-packages/setuptools/__init__.py", line 154, in setup
#           _install_setup_requires(attrs)
#         File "/opt/conda/envs/openmmlab/lib/python3.10/site-packages/setuptools/__init__.py", line 146, in _install_setup_requires
#           dist.parse_config_files(ignore_option_errors=True)
#         File "/opt/conda/envs/openmmlab/lib/python3.10/site-packages/setuptools/dist.py", line 804, in parse_config_files
#           parse_configuration(
#         File "/opt/conda/envs/openmmlab/lib/python3.10/site-packages/setuptools/config/__init__.py", line 36, in _wrapper
#           return fn(*args, **kwargs)
#         File "/opt/conda/envs/openmmlab/lib/python3.10/site-packages/setuptools/config/setupcfg.py", line 190, in parse_configuration
#           distribution._referenced_files.update(
#       AttributeError: 'MinimalDistribution' object has no attribute '_referenced_files'
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Requirement already satisfied: ftfy in /home/codespace/.local/lib/python3.10/site-packages (6.1.3)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /home/codespace/.local/lib/python3.10/site-packages (from ftfy) (0.2.12)
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu121/torch2.1.0/index.html
# Requirement already satisfied: mmsegmentation in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (1.2.1)
# Requirement already satisfied: matplotlib in /home/codespace/.local/lib/python3.10/site-packages (from mmsegmentation) (3.8.1)
# Requirement already satisfied: numpy in /home/codespace/.local/lib/python3.10/site-packages (from mmsegmentation) (1.26.2)
# Requirement already satisfied: packaging in /home/codespace/.local/lib/python3.10/site-packages (from mmsegmentation) (23.2)
# Requirement already satisfied: prettytable in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from mmsegmentation) (3.9.0)
# Requirement already satisfied: scipy in /home/codespace/.local/lib/python3.10/site-packages (from mmsegmentation) (1.11.3)
# Requirement already satisfied: mmcv<2.2.0,>=2.0.0rc4 in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from mmsegmentation) (2.1.0)
# Requirement already satisfied: mmengine<1.0.0,>=0.5.0 in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from mmsegmentation) (0.10.1)
# Requirement already satisfied: addict in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from mmcv<2.2.0,>=2.0.0rc4->mmsegmentation) (2.4.0)
# Requirement already satisfied: Pillow in /home/codespace/.local/lib/python3.10/site-packages (from mmcv<2.2.0,>=2.0.0rc4->mmsegmentation) (10.1.0)
# Requirement already satisfied: pyyaml in /home/codespace/.local/lib/python3.10/site-packages (from mmcv<2.2.0,>=2.0.0rc4->mmsegmentation) (6.0.1)
# Requirement already satisfied: yapf in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from mmcv<2.2.0,>=2.0.0rc4->mmsegmentation) (0.40.2)
# Requirement already satisfied: opencv-python>=3 in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from mmcv<2.2.0,>=2.0.0rc4->mmsegmentation) (4.8.1.78)
# Requirement already satisfied: rich in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from mmengine<1.0.0,>=0.5.0->mmsegmentation) (13.4.2)
# Requirement already satisfied: termcolor in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from mmengine<1.0.0,>=0.5.0->mmsegmentation) (2.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->mmsegmentation) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->mmsegmentation) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->mmsegmentation) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->mmsegmentation) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->mmsegmentation) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->mmsegmentation) (2.8.2)
# Requirement already satisfied: wcwidth in /home/codespace/.local/lib/python3.10/site-packages (from prettytable->mmsegmentation) (0.2.12)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->mmsegmentation) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from rich->mmengine<1.0.0,>=0.5.0->mmsegmentation) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/codespace/.local/lib/python3.10/site-packages (from rich->mmengine<1.0.0,>=0.5.0->mmsegmentation) (2.16.1)
# Requirement already satisfied: importlib-metadata>=6.6.0 in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from yapf->mmcv<2.2.0,>=2.0.0rc4->mmsegmentation) (7.0.0)
# Requirement already satisfied: platformdirs>=3.5.1 in /home/codespace/.local/lib/python3.10/site-packages (from yapf->mmcv<2.2.0,>=2.0.0rc4->mmsegmentation) (4.0.0)
# Requirement already satisfied: tomli>=2.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from yapf->mmcv<2.2.0,>=2.0.0rc4->mmsegmentation) (2.0.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from importlib-metadata>=6.6.0->yapf->mmcv<2.2.0,>=2.0.0rc4->mmsegmentation) (3.17.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/envs/openmmlab/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->mmengine<1.0.0,>=0.5.0->mmsegmentation) (0.1.2)

# %%
import torch, torchvision
print(torch.__version__, torch.cuda.is_available())
assert torch.cuda.is_available() == True, "GPU not available"

from mmsegmentation import mmseg
print(mmseg.__version__)
# Out:
# 2.1.1+cu121 True
# 1.2.1
