# %% [markdown]
# ## MMSegmentation Package Setup

# %%
# Install mim
# !pip install -U openmim
# Install mmengine
# !mim install mmengine
# Install MMCV
# !mim install 'mmcv >= 2.0.0rc1'
# Install CV2 
# !pip install opencv-python opencv-python-headless
# Install MMSegmentation
# !rm -rf mmsegmentation
# !git clone -b main https://github.com/open-mmlab/mmsegmentation.git
# %cd mmsegmentation
# !pip install -e .
# Out:
# Requirement already satisfied: openmim in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (0.3.9)
# Requirement already satisfied: Click in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from openmim) (8.1.7)
# Requirement already satisfied: colorama in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from openmim) (0.4.6)
# Requirement already satisfied: model-index in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from openmim) (0.1.11)
# Requirement already satisfied: opendatalab in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from openmim) (0.0.10)
# Requirement already satisfied: pandas in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from openmim) (2.0.3)
# Requirement already satisfied: pip>=19.3 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from openmim) (23.3.1)
# Requirement already satisfied: requests in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from openmim) (2.28.2)
# Requirement already satisfied: rich in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from openmim) (13.4.2)
# Requirement already satisfied: tabulate in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from openmim) (0.9.0)
# Requirement already satisfied: pyyaml in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from model-index->openmim) (6.0.1)
# Requirement already satisfied: markdown in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from model-index->openmim) (3.5.1)
# Requirement already satisfied: ordered-set in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from model-index->openmim) (4.1.0)
# Requirement already satisfied: pycryptodome in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from opendatalab->openmim) (3.19.0)
# Requirement already satisfied: tqdm in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from opendatalab->openmim) (4.65.2)
# Requirement already satisfied: openxlab in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from opendatalab->openmim) (0.0.30)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from requests->openmim) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from requests->openmim) (3.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from requests->openmim) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from requests->openmim) (2023.11.17)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from pandas->openmim) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from pandas->openmim) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from pandas->openmim) (2023.3)
# Requirement already satisfied: numpy>=1.20.3 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from pandas->openmim) (1.24.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from rich->openmim) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from rich->openmim) (2.17.2)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from rich->openmim) (4.8.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from markdown-it-py>=2.2.0->rich->openmim) (0.1.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas->openmim) (1.16.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from markdown->model-index->openmim) (7.0.0)
# Requirement already satisfied: oss2~=2.17.0 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from openxlab->opendatalab->openmim) (2.17.0)
# Requirement already satisfied: setuptools~=60.2.0 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from openxlab->opendatalab->openmim) (60.2.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown->model-index->openmim) (3.17.0)
# Requirement already satisfied: crcmod>=1.7 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim) (1.7)
# Requirement already satisfied: aliyun-python-sdk-kms>=2.4.1 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim) (2.16.2)
# Requirement already satisfied: aliyun-python-sdk-core>=2.13.12 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim) (2.14.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.9.3 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (0.10.0)
# Requirement already satisfied: cryptography>=2.6.0 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (41.0.7)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from cryptography>=2.6.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (1.16.0)
# Requirement already satisfied: pycparser in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from cffi>=1.12->cryptography>=2.6.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (2.21)
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu121/torch2.1.0/index.html
# Collecting mmengine
#   Downloading mmengine-0.10.1-py3-none-any.whl.metadata (20 kB)
# Collecting addict (from mmengine)
#   Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: matplotlib in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from mmengine) (3.7.4)
# Requirement already satisfied: numpy in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from mmengine) (1.24.4)
# Requirement already satisfied: pyyaml in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from mmengine) (6.0.1)
# Requirement already satisfied: rich in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from mmengine) (13.4.2)
# Collecting termcolor (from mmengine)
#   Downloading termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting yapf (from mmengine)
#   Downloading yapf-0.40.2-py3-none-any.whl.metadata (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 1.0 MB/s eta 0:00:00ta 0:00:01
# Requirement already satisfied: opencv-python>=3 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from mmengine) (4.8.1.78)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from matplotlib->mmengine) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from matplotlib->mmengine) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from matplotlib->mmengine) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from matplotlib->mmengine) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from matplotlib->mmengine) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from matplotlib->mmengine) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from matplotlib->mmengine) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from matplotlib->mmengine) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from matplotlib->mmengine) (6.1.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from rich->mmengine) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from rich->mmengine) (2.17.2)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from rich->mmengine) (4.8.0)
# Requirement already satisfied: importlib-metadata>=6.6.0 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from yapf->mmengine) (7.0.0)
# Requirement already satisfied: platformdirs>=3.5.1 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from yapf->mmengine) (4.1.0)
# Collecting tomli>=2.0.1 (from yapf->mmengine)
#   Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from importlib-metadata>=6.6.0->yapf->mmengine) (3.17.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from markdown-it-py>=2.2.0->rich->mmengine) (0.1.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib->mmengine) (1.16.0)
# Downloading mmengine-0.10.1-py3-none-any.whl (450 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 450.3/450.3 kB 7.6 MB/s eta 0:00:00:00:01
# Downloading termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Downloading yapf-0.40.2-py3-none-any.whl (254 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.7/254.7 kB 5.7 MB/s eta 0:00:00ta 0:00:01
# Installing collected packages: addict, tomli, termcolor, yapf, mmengine
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mmsegmentation 1.2.1 requires mmcv<2.2.0,>=2.0.0rc4, which is not installed.
# Successfully installed addict-2.4.0 mmengine-0.10.1 termcolor-2.4.0 tomli-2.0.1 yapf-0.40.2
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu121/torch2.1.0/index.html
# Collecting mmcv>=2.0.0rc1
#   Downloading https://download.openmmlab.com/mmcv/dist/cu121/torch2.1.0/mmcv-2.1.0-cp38-cp38-manylinux1_x86_64.whl (94.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.1/94.1 MB 14.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: addict in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from mmcv>=2.0.0rc1) (2.4.0)
# Requirement already satisfied: mmengine>=0.3.0 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from mmcv>=2.0.0rc1) (0.10.1)
# Requirement already satisfied: numpy in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from mmcv>=2.0.0rc1) (1.24.4)
# Requirement already satisfied: packaging in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from mmcv>=2.0.0rc1) (23.2)
# Requirement already satisfied: Pillow in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from mmcv>=2.0.0rc1) (10.1.0)
# Requirement already satisfied: pyyaml in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from mmcv>=2.0.0rc1) (6.0.1)
# Requirement already satisfied: yapf in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from mmcv>=2.0.0rc1) (0.40.2)
# Requirement already satisfied: opencv-python>=3 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from mmcv>=2.0.0rc1) (4.8.1.78)
# Requirement already satisfied: matplotlib in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from mmengine>=0.3.0->mmcv>=2.0.0rc1) (3.7.4)
# Requirement already satisfied: rich in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from mmengine>=0.3.0->mmcv>=2.0.0rc1) (13.4.2)
# Requirement already satisfied: termcolor in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from mmengine>=0.3.0->mmcv>=2.0.0rc1) (2.4.0)
# Requirement already satisfied: importlib-metadata>=6.6.0 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from yapf->mmcv>=2.0.0rc1) (7.0.0)
# Requirement already satisfied: platformdirs>=3.5.1 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from yapf->mmcv>=2.0.0rc1) (4.1.0)
# Requirement already satisfied: tomli>=2.0.1 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from yapf->mmcv>=2.0.0rc1) (2.0.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from importlib-metadata>=6.6.0->yapf->mmcv>=2.0.0rc1) (3.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc1) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc1) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc1) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc1) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc1) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc1) (6.1.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from rich->mmengine>=0.3.0->mmcv>=2.0.0rc1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from rich->mmengine>=0.3.0->mmcv>=2.0.0rc1) (2.17.2)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from rich->mmengine>=0.3.0->mmcv>=2.0.0rc1) (4.8.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from markdown-it-py>=2.2.0->rich->mmengine>=0.3.0->mmcv>=2.0.0rc1) (0.1.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc1) (1.16.0)
# Installing collected packages: mmcv
# Successfully installed mmcv-2.1.0
# Requirement already satisfied: opencv-python in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (4.8.1.78)
# Requirement already satisfied: opencv-python-headless in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (4.8.1.78)
# Requirement already satisfied: numpy>=1.17.0 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from opencv-python) (1.24.4)
# Cloning into 'mmsegmentation'...
# remote: Enumerating objects: 16316, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 16316 (delta 4), reused 15 (delta 0), pack-reused 16289
# Receiving objects: 100% (16316/16316), 23.22 MiB | 39.23 MiB/s, done.
# Resolving deltas: 100% (11377/11377), done.
# /workspaces/ECE661GroupProject_TransferLearning/mmsegmentation
# Obtaining file:///workspaces/ECE661GroupProject_TransferLearning/mmsegmentation
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from mmsegmentation==1.2.1) (3.7.4)
# Requirement already satisfied: numpy in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from mmsegmentation==1.2.1) (1.24.4)
# Requirement already satisfied: packaging in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from mmsegmentation==1.2.1) (23.2)
# Requirement already satisfied: prettytable in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from mmsegmentation==1.2.1) (3.9.0)
# Requirement already satisfied: scipy in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from mmsegmentation==1.2.1) (1.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from matplotlib->mmsegmentation==1.2.1) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from matplotlib->mmsegmentation==1.2.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from matplotlib->mmsegmentation==1.2.1) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from matplotlib->mmsegmentation==1.2.1) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from matplotlib->mmsegmentation==1.2.1) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from matplotlib->mmsegmentation==1.2.1) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from matplotlib->mmsegmentation==1.2.1) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from matplotlib->mmsegmentation==1.2.1) (6.1.1)
# Requirement already satisfied: wcwidth in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from prettytable->mmsegmentation==1.2.1) (0.2.12)
# Requirement already satisfied: zipp>=3.1.0 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib->mmsegmentation==1.2.1) (3.17.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/openmmlab/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib->mmsegmentation==1.2.1) (1.16.0)
# Installing collected packages: mmsegmentation
#   Running setup.py develop for mmsegmentation
# Successfully installed mmsegmentation-1.2.1

# %%
# Check Pytorch installation
import torch.torchvision
print(torch.__version__, torch.cuda.is_available())
# Check MMSegmentation installation
from mmsegmentation import mmseg
print(mmseg.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /workspaces/ECE661GroupProject_TransferLearning/1_setup.ipynb Cell 3 line 2
#       <a href='vscode-notebook-cell://codespaces%2Bstunning-guide-xprpq76gpxqcvgv5/workspaces/ECE661GroupProject_TransferLearning/1_setup.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> # Check Pytorch installation
# ----> <a href='vscode-notebook-cell://codespaces%2Bstunning-guide-xprpq76gpxqcvgv5/workspaces/ECE661GroupProject_TransferLearning/1_setup.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> import torch.torchvision
#       <a href='vscode-notebook-cell://codespaces%2Bstunning-guide-xprpq76gpxqcvgv5/workspaces/ECE661GroupProject_TransferLearning/1_setup.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> print(torch.__version__, torch.cuda.is_available())
#       <a href='vscode-notebook-cell://codespaces%2Bstunning-guide-xprpq76gpxqcvgv5/workspaces/ECE661GroupProject_TransferLearning/1_setup.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> # Check MMSegmentation installation
#
# ModuleNotFoundError: No module named 'torch.torchvision'
